# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer


# !pip install -q optuna

import lightgbm as lgb
from sklearn import metrics

# %%
df = pd.read_csv('/kaggle/input/playground-series-s3e25/train.csv')

# %%
df.head()
# Out:
#    id  allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0   0               100.0       0.841611                  10.0            4.8
# 1   1               100.0       7.558488                  10.0            4.8
# 2   2                76.0       8.885992                  15.6            5.6
# 3   3               100.0       8.795296                  10.0            4.8
# 4   4               116.0       9.577996                  11.6            4.8
#
#    atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 0             20.612526           11.08810               2.766
# 1             20.298893           12.04083               2.755
# 2             33.739258           12.08630               2.828
# 3             20.213349           10.94850               2.648
# 4             24.988133           11.82448               2.766
#
#    R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# 0                  1.732                  0.860         0.496070
# 1                  1.631                  0.910         0.492719
# 2                  1.788                  0.864         0.481478
# 3                  1.626                  0.936         0.489272
# 4                  1.682                  0.896         0.492736
#
#    density_Average  Hardness
# 0          0.91457       6.0
# 1          0.71760       6.5
# 2          1.50633       2.5
# 3          0.78937       6.0
# 4          1.86481       6.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10407 entries, 0 to 10406
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     10407 non-null  int64
#  1   allelectrons_Total     10407 non-null  float64
#  2   density_Total          10407 non-null  float64
#  3   allelectrons_Average   10407 non-null  float64
#  4   val_e_Average          10407 non-null  float64
#  5   atomicweight_Average   10407 non-null  float64
#  6   ionenergy_Average      10407 non-null  float64
#  7   el_neg_chi_Average     10407 non-null  float64
#  8   R_vdw_element_Average  10407 non-null  float64
#  9   R_cov_element_Average  10407 non-null  float64
#  10  zaratio_Average        10407 non-null  float64
#  11  density_Average        10407 non-null  float64
#  12  Hardness               10407 non-null  float64
# dtypes: float64(12), int64(1)
# memory usage: 1.0 MB

# %%
df.isnull().sum()
# Out:
# id                       0
# allelectrons_Total       0
# density_Total            0
# allelectrons_Average     0
# val_e_Average            0
# atomicweight_Average     0
# ionenergy_Average        0
# el_neg_chi_Average       0
# R_vdw_element_Average    0
# R_cov_element_Average    0
# zaratio_Average          0
# density_Average          0
# Hardness                 0
# dtype: int64

# %%
df.describe()
# Out:
#                 id  allelectrons_Total  density_Total  allelectrons_Average  \
# count  10407.00000        10407.000000   10407.000000          10407.000000
# mean    5203.00000          128.053516      14.491342             17.033222
# std     3004.38646          224.123776      15.972877             10.468734
# min        0.00000            0.000000       0.000000              0.000000
# 25%     2601.50000           68.000000       7.558488             10.000000
# 50%     5203.00000          100.000000      10.650000             12.600000
# 75%     7804.50000          131.000000      16.676996             22.000000
# max    10406.00000        15300.000000     643.093804             67.000000
#
#        val_e_Average  atomicweight_Average  ionenergy_Average  \
# count   10407.000000          10407.000000       10407.000000
# mean        4.546789             37.507703          10.938308
# std         0.690864             26.012313           1.408276
# min         0.000000              0.000000           0.000000
# 25%         4.000000             20.298893          10.590660
# 50%         4.714286             26.203827          11.202760
# 75%         4.800000             48.719500          11.670725
# max         6.000000            167.400000          15.245810
#
#        el_neg_chi_Average  R_vdw_element_Average  R_cov_element_Average  \
# count        10407.000000           10407.000000           10407.000000
# mean             2.607662               1.731330               0.944132
# std              0.334906               0.192481               0.180017
# min              0.000000               0.000000               0.000000
# 25%              2.530000               1.672500               0.864000
# 50%              2.706000               1.732727               0.915556
# 75%              2.805000               1.800000               0.981667
# max              3.443000               2.250000               1.615840
#
#        zaratio_Average  density_Average      Hardness
# count     10407.000000     10407.000000  10407.000000
# mean          0.493349         2.132984      4.647126
# std           0.063080         1.936656      1.680525
# min           0.000000         0.000000      1.000000
# 25%           0.476196         0.814800      3.000000
# 50%           0.488550         1.351550      5.500000
# 75%           0.496070         2.741550      6.000000
# max           0.825990        10.970000     10.000000

# %%
df = df.drop(columns=['id'])
df
# Out:
#        allelectrons_Total  density_Total  allelectrons_Average  val_e_Average  \
# 0                   100.0       0.841611             10.000000       4.800000
# 1                   100.0       7.558488             10.000000       4.800000
# 2                    76.0       8.885992             15.600000       5.600000
# 3                   100.0       8.795296             10.000000       4.800000
# 4                   116.0       9.577996             11.600000       4.800000
# ...                   ...            ...                   ...            ...
# 10402               128.0       7.558488             12.000000       4.000000
# 10403                30.0       1.743160             10.000000       5.333333
# 10404               196.0      30.920000             24.500000       5.500000
# 10405                38.0       1.553160             12.666667       4.666667
# 10406               288.0      24.655328             11.142857       4.571429
#
#        atomicweight_Average  ionenergy_Average  el_neg_chi_Average  \
# 0                 20.612526          11.088100            2.766000
# 1                 20.298893          12.040830            2.755000
# 2                 33.739258          12.086300            2.828000
# 3                 20.213349          10.948500            2.648000
# 4                 24.988133          11.824480            2.766000
# ...                     ...                ...                 ...
# 10402             26.385218          11.330440            2.644000
# 10403             20.766935          14.163933            3.090000
# 10404             53.490297          10.074300            2.295000
# 10405             26.621687          11.290033            2.743333
# 10406             22.536126          10.960357            2.792143
#
#        R_vdw_element_Average  R_cov_element_Average  zaratio_Average  \
# 0                   1.732000               0.860000         0.496070
# 1                   1.631000               0.910000         0.492719
# 2                   1.788000               0.864000         0.481478
# 3                   1.626000               0.936000         0.489272
# 4                   1.682000               0.896000         0.492736
# ...                      ...                    ...              ...
# 10402               1.631000               0.892000         0.496070
# 10403               1.556667               0.866667         0.480390
# 10404               1.545000               1.120000         0.469715
# 10405               1.756667               0.980000         0.486507
# 10406               1.772857               0.940000         0.493919
#
#        density_Average  Hardness
# 0              0.91457       6.0
# 1              0.71760       6.5
# 2              1.50633       2.5
# 3              0.78937       6.0
# 4              1.86481       6.0
# ...                ...       ...
# 10402          1.79607       4.0
# 10403          0.81480       5.0
# 10404          2.11540       1.8
# 10405          0.77755       6.0
# 10406          0.97737       6.5
#
# [10407 rows x 12 columns]

# %%
num_features = df.select_dtypes(include=[np.number]).columns
num_features
# Out:
# Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Hardness'],
#       dtype='object')

# %%
num_bins = int(np.sqrt(len(df)))
for col in num_features:
    plt.figure(figsize=(12, 6))
    
    # select non empty 
    col_data = df[col].dropna()
    
    # Histogram
    counts, bin_edges = np.histogram(col_data, bins=num_bins)
    plt.hist(col_data, bins=num_bins, edgecolor='k', alpha=0.7)
    plt.title(f'Histogramm {col}', fontsize=14)
    plt.xlabel(col, fontsize=12)
    plt.ylabel('frequency', fontsize=12)
    plt.grid(True)
    plt.show()

# %%
y = df['Hardness']
X = df.drop(columns='Hardness')

# %%
y.describe()
# Out:
# count    10407.000000
# mean         4.647126
# std          1.680525
# min          1.000000
# 25%          3.000000
# 50%          5.500000
# 75%          6.000000
# max         10.000000
# Name: Hardness, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.1,
                                                    random_state=42)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                  train_size=0.8/0.9,
                                                  random_state=42)

print(f'Train: {X_train.shape[0]} - {round(X_train.shape[0] / X.shape[0] * 100)}%')
print(f'Test:  {X_test.shape[0]} - {round(X_test.shape[0] / X.shape[0] * 100)}%')
print(f'Val:   {X_val.shape[0]} - {round(X_val.shape[0] / X.shape[0] * 100)}%')
# Out:
# Train: 8325 - 80%
# Test:  1041 - 10%
# Val:   1041 - 10%

# %%
num_columns = X.select_dtypes(include="number").columns

num_transformer = Pipeline(
    steps=[("imputer", SimpleImputer(strategy="median"))]
)

preprocessor = ColumnTransformer(
    transformers=[
        ("num", num_transformer, num_columns),
    ]
)

preprocessor.set_output(transform='pandas')

preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median'))]),
#                                  Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average'],
#       dtype='object'))])

# %%
X_train = preprocessor.fit_transform(X_train)
X_val = preprocessor.transform(X_val)
X_test = preprocessor.transform(X_test)

# %%
def objective(trial):

  # Hiperparameters:

  model = lgb.LGBMRegressor(
        n_estimators = 30,
        verbose = -1,
        max_depth = trial.suggest_int('max_depth', 4, 30),
        lambda_l1 = trial.suggest_float('lambda_l1', 1e-5, 1, log=True),
        lambda_l2 = trial.suggest_float('lambda_l2', 1e-5, 1, log=True),
        num_leaves = trial.suggest_int('num_leaves', 5, 120),
        objective = trial.suggest_categorical('objective', ['mse', 'mae', 'huber']),
        alpha = trial.suggest_float('alpha', 1, 10, log=True)
  )


  # Model training:

  model.fit(X_train, y_train)

  # Model estimation:
  y_pred = model.predict(X_val)
  r2 = metrics.r2_score(y_val, y_pred)

  # 5. Metrics:
  return r2

# %%
import optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)
# Out:
# [I 2024-12-09 00:30:02,075] A new study created in memory with name: no-name-ff430091-3ac2-4efa-ad6a-484187efaac0
# [I 2024-12-09 00:30:02,419] Trial 0 finished with value: 0.4655658652174366 and parameters: {'max_depth': 23, 'lambda_l1': 0.005399696501817073, 'lambda_l2': 0.30878629763204524, 'num_leaves': 32, 'objective': 'mse', 'alpha': 2.1818059690232503}. Best is trial 0 with value: 0.4655658652174366.
# [I 2024-12-09 00:30:02,624] Trial 1 finished with value: 0.46435292536607287 and parameters: {'max_depth': 14, 'lambda_l1': 1.4626905501483689e-05, 'lambda_l2': 0.008668166104986682, 'num_leaves': 115, 'objective': 'huber', 'alpha': 1.130696594369893}. Best is trial 0 with value: 0.4655658652174366.
# [I 2024-12-09 00:30:02,740] Trial 2 finished with value: 0.46956250348077877 and parameters: {'max_depth': 23, 'lambda_l1': 7.700001299822649e-05, 'lambda_l2': 0.0006969998576040083, 'num_leaves': 50, 'objective': 'mse', 'alpha': 2.144357599562052}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:02,801] Trial 3 finished with value: 0.42195149643969077 and parameters: {'max_depth': 22, 'lambda_l1': 0.00019209146911622514, 'lambda_l2': 0.17811638137125052, 'num_leaves': 10, 'objective': 'huber', 'alpha': 2.9173984194044835}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:02,862] Trial 4 finished with value: 0.43686151711656296 and parameters: {'max_depth': 4, 'lambda_l1': 0.9770281970260324, 'lambda_l2': 0.002866901224105447, 'num_leaves': 46, 'objective': 'mse', 'alpha': 2.5217562682490318}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:02,952] Trial 5 finished with value: 0.4490718098033072 and parameters: {'max_depth': 18, 'lambda_l1': 2.9461301203684825e-05, 'lambda_l2': 0.011193000702982571, 'num_leaves': 26, 'objective': 'huber', 'alpha': 3.094011351747022}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:03,036] Trial 6 finished with value: 0.4529493953606474 and parameters: {'max_depth': 8, 'lambda_l1': 0.003272657131283488, 'lambda_l2': 4.1670872115584874e-05, 'num_leaves': 22, 'objective': 'mse', 'alpha': 1.073525815319374}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:03,141] Trial 7 finished with value: 0.4634756427263338 and parameters: {'max_depth': 15, 'lambda_l1': 0.0004330953932095664, 'lambda_l2': 0.015304083286925906, 'num_leaves': 37, 'objective': 'huber', 'alpha': 2.922060910826096}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:03,345] Trial 8 finished with value: 0.45163252040516866 and parameters: {'max_depth': 17, 'lambda_l1': 0.008842934968930127, 'lambda_l2': 0.005209516297478601, 'num_leaves': 102, 'objective': 'mae', 'alpha': 7.537806915258809}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:03,417] Trial 9 finished with value: 0.4407536392297263 and parameters: {'max_depth': 19, 'lambda_l1': 0.6562143324529819, 'lambda_l2': 0.14163698026355234, 'num_leaves': 12, 'objective': 'mse', 'alpha': 1.112175213762338}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:03,650] Trial 10 finished with value: 0.446334058082398 and parameters: {'max_depth': 30, 'lambda_l1': 0.03920475576849708, 'lambda_l2': 0.00010118625854603082, 'num_leaves': 74, 'objective': 'mae', 'alpha': 6.807693215347165}. Best is trial 2 with value: 0.46956250348077877.
# [I 2024-12-09 00:30:03,814] Trial 11 finished with value: 0.4765198411005994 and parameters: {'max_depth': 26, 'lambda_l1': 0.0004945790659308888, 'lambda_l2': 0.00044666510563813627, 'num_leaves': 65, 'objective': 'mse', 'alpha': 1.9829799756621203}. Best is trial 11 with value: 0.4765198411005994.
# [I 2024-12-09 00:30:03,979] Trial 12 finished with value: 0.47651989907912473 and parameters: {'max_depth': 29, 'lambda_l1': 0.0002698675599456813, 'lambda_l2': 0.0005054480408862827, 'num_leaves': 65, 'objective': 'mse', 'alpha': 1.9461737883223806}. Best is trial 12 with value: 0.47651989907912473.
# [I 2024-12-09 00:30:04,157] Trial 13 finished with value: 0.4720640989192134 and parameters: {'max_depth': 30, 'lambda_l1': 0.000599882459846911, 'lambda_l2': 0.00018667020508666182, 'num_leaves': 74, 'objective': 'mse', 'alpha': 1.7064793881949134}. Best is trial 12 with value: 0.47651989907912473.
# [I 2024-12-09 00:30:04,324] Trial 14 finished with value: 0.47923408575315884 and parameters: {'max_depth': 27, 'lambda_l1': 0.0006389494255209942, 'lambda_l2': 0.0006664108513568575, 'num_leaves': 66, 'objective': 'mse', 'alpha': 4.674907246814521}. Best is trial 14 with value: 0.47923408575315884.
# [I 2024-12-09 00:30:04,513] Trial 15 finished with value: 0.47862626958763643 and parameters: {'max_depth': 27, 'lambda_l1': 0.027025192559035936, 'lambda_l2': 2.5659638518080958e-05, 'num_leaves': 87, 'objective': 'mse', 'alpha': 5.073312387803384}. Best is trial 14 with value: 0.47923408575315884.
# [I 2024-12-09 00:30:04,730] Trial 16 finished with value: 0.4499048392157641 and parameters: {'max_depth': 26, 'lambda_l1': 0.06236644039627489, 'lambda_l2': 1.255099286353762e-05, 'num_leaves': 91, 'objective': 'mae', 'alpha': 4.59457965977816}. Best is trial 14 with value: 0.47923408575315884.
# [I 2024-12-09 00:30:04,926] Trial 17 finished with value: 0.4746226280022239 and parameters: {'max_depth': 26, 'lambda_l1': 0.01692787058595641, 'lambda_l2': 1.02808189820205e-05, 'num_leaves': 87, 'objective': 'mse', 'alpha': 4.688372127058054}. Best is trial 14 with value: 0.47923408575315884.
# [I 2024-12-09 00:30:05,114] Trial 18 finished with value: 0.4797139507261887 and parameters: {'max_depth': 12, 'lambda_l1': 0.09336835669763344, 'lambda_l2': 0.001614390370698398, 'num_leaves': 88, 'objective': 'mse', 'alpha': 4.835862277157094}. Best is trial 18 with value: 0.4797139507261887.
# [I 2024-12-09 00:30:05,334] Trial 19 finished with value: 0.4580014256844104 and parameters: {'max_depth': 11, 'lambda_l1': 0.15949630075819313, 'lambda_l2': 0.03396354566536014, 'num_leaves': 114, 'objective': 'mae', 'alpha': 9.239304467487308}. Best is trial 18 with value: 0.4797139507261887.

# %%
study.best_params
# Out:
# {'max_depth': 12,
#  'lambda_l1': 0.09336835669763344,
#  'lambda_l2': 0.001614390370698398,
#  'num_leaves': 88,
#  'objective': 'mse',
#  'alpha': 4.835862277157094}

# %%
best_params = study.best_params
model = lgb.LGBMRegressor(**best_params,n_estimators = 25,verbose=-1)

model.fit(X_train, y_train,
          eval_set=[(X_test, y_test), (X_train, y_train)],
          eval_metric='mae')
# Out:
# LGBMRegressor(alpha=4.835862277157094, lambda_l1=0.09336835669763344,
#               lambda_l2=0.001614390370698398, max_depth=12, n_estimators=25,
#               num_leaves=88, objective='mse', verbose=-1)

# %%
lgb.plot_metric(model,metric='l1')
# Out:
# <Axes: title={'center': 'Metric during training'}, xlabel='Iterations', ylabel='l1'>

# %%
def get_metrics(y_true, y_pred, name="model"):
  df = pd.DataFrame()

  df.loc["MAE", name] = metrics.mean_absolute_error(y_true, y_pred)
  df.loc["RMSE", name] = metrics.mean_squared_error(y_true, y_pred) ** 0.5
  df.loc["R2", name] = metrics.r2_score(y_true, y_pred)

  return df.round(2)

# %%
df_metrics = pd.DataFrame()

df_metrics["train"] = get_metrics(y_train, model.predict(X_train))
df_metrics["test"] = get_metrics(y_test, model.predict(X_test))
df_metrics
# Out:
#       train  test
# MAE    0.79  0.89
# RMSE   1.05  1.17
# R2     0.61  0.51

# %%
optuna.visualization.plot_param_importances(study)
lgb.plot_importance(model)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>
