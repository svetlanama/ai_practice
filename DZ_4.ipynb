# %% [markdown]
# <a href="https://colab.research.google.com/github/svetlanama/ai_practice/blob/dev/DZ_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Імпорт модулів та даних

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module2/data/possum.csv")

# %%
df.head()
# Out:
#    case  site  Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0     1     1  Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1     2     1  Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2     3     1  Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3     4     1  Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4     5     1  Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
#
#    earconch   eye  chest  belly
# 0      54.5  15.2   28.0   36.0
# 1      51.2  16.0   28.5   33.0
# 2      51.9  15.5   30.0   34.0
# 3      52.2  15.2   28.0   34.0
# 4      53.2  15.1   28.5   33.0

# %% [markdown]
# # Завдання 1
# Виведіть основні числові характеристики для числових ознак

# %%
df.shape
# Out:
# (104, 14)

# %%
df.size
# Out:
# 1456

# %%
df.describe()
# Out:
#              case        site         age     hdlngth      skullw    totlngth  \
# count  104.000000  104.000000  102.000000  104.000000  104.000000  104.000000
# mean    52.500000    3.625000    3.833333   92.602885   56.883654   87.088462
# std     30.166206    2.349086    1.909244    3.573349    3.113426    4.310549
# min      1.000000    1.000000    1.000000   82.500000   50.000000   75.000000
# 25%     26.750000    1.000000    2.250000   90.675000   54.975000   84.000000
# 50%     52.500000    3.000000    3.000000   92.800000   56.350000   88.000000
# 75%     78.250000    6.000000    5.000000   94.725000   58.100000   90.000000
# max    104.000000    7.000000    9.000000  103.100000   68.600000   96.500000
#
#             taill    footlgth    earconch         eye       chest       belly
# count  104.000000  103.000000  104.000000  104.000000  104.000000  104.000000
# mean    37.009615   68.459223   48.130769   15.046154   27.000000   32.586538
# ...

# %% [markdown]
# # Завдання 2
# Проаналізуйте стовпчик `case`, чи є він інформативним?

# %%
df['case'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: case, dtype: int64

# %%
df['case'].sum()
# Out:
# 5460

# %%
df['case']. value_counts()
# Out:
# case
# 1      1
# 2      1
# 77     1
# 76     1
# 75     1
#       ..
# 32     1
# 31     1
# 30     1
# 29     1
# 104    1
# Name: count, Length: 104, dtype: int64

# %% [markdown]
# # Завдання 3
# Очистіть дані від викидів. Виведіть очищений датафрейм

# %%
df_copy = df.copy()
num_columns = df_new.select_dtypes(include="number").columns

num = df_copy[num_columns]
q1 = num.quantile(q=0.25)
q3 = num.quantile(q=0.75)

iqr = q3 - q1
print('iqr:', iqr)

lower = q1 - 1.5*iqr
upper = q3 + 1.5*iqr

mask = (num >= lower) & (num <= upper)
mask = mask.all(axis=1)

clean_df = df[mask]
clean_df
# Out:
# iqr: case        51.500
# site         5.000
# age          2.750
# hdlngth      4.050
# skullw       3.125
# totlngth     6.000
# taill        2.125
# footlgth     7.900
# earconch     7.200
# eye          1.325
# chest        2.500
# belly        3.125
# dtype: float64
#      case  site    Pop sex  age  hdlngth  skullw  totlngth  taill  footlgth  \
# 0       1     1    Vic   m  8.0     94.1    60.4      89.0   36.0      74.5
# 1       2     1    Vic   f  6.0     92.5    57.6      91.5   36.5      72.5
# 2       3     1    Vic   f  6.0     94.0    60.0      95.5   39.0      75.4
# 3       4     1    Vic   f  6.0     93.2    57.1      92.0   38.0      76.1
# 4       5     1    Vic   f  2.0     91.5    56.3      85.5   36.0      71.0
# ..    ...   ...    ...  ..  ...      ...     ...       ...    ...       ...
# 99    100     7  other   m  1.0     89.5    56.0      81.5   36.5      66.0
# 100   101     7  other   m  1.0     88.6    54.7      82.5   39.0      64.4
# ...

# %% [markdown]
# # Завдання 4
# Намалюйте матрицб кореляцій. Для найбільш корельованих ознак намалюйте точкову діаграму.

# %%
df.plot(kind='scatter', x='hdlngth', y='taill', figsize=(8,8))
# Out:
# <Axes: xlabel='hdlngth', ylabel='taill'>

# %% [markdown]
# # Завдання 5
# Для 4-ох числових ознак на вибір намалюйте ящики з вусами згрупованими по статі. Подумайте чи є вплив статі на розміри опосума

# %%
# case	site	Pop	sex	age	hdlngth	skullw	totlngth	taill	footlgth	earconch	eye	chest	belly
df['age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
# case	site	age	hdlngth	skullw	totlngth	taill	footlgth	earconch	eye	chest	belly
df['case'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
# case	site	age	hdlngth	skullw	totlngth	taill	footlgth	earconch	eye	chest	belly
df['eye'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %%
# case	site	age	hdlngth	skullw	totlngth	taill	footlgth	earconch	eye	chest	belly
df['taill'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >
