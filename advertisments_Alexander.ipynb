# %% [markdown]
# <a href="https://colab.research.google.com/github/svetlanama/ai_practice/blob/dev/advertisments_Alexander.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title

# %% [markdown]
# IT Step

# %%
num = 10
num += 1
print(num)
# Out:
# 11

# %%
print(num)
# Out:
# 11
