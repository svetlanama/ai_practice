# %% [markdown]
# <a href="https://colab.research.google.com/github/svetlanama/ai_practice/blob/dev/DZ_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ваша задача методом градієнтного спуску знайти коефіцієнти для задачі регресії. Обираємо метод лінійної регресії та дані про діаманти

# %%
import pandas as pd
import torch

# %%
df = pd.read_csv("https://raw.githubusercontent.com/HalyshAnton/IT-Step-Pyton-AI/main/module3/data/diamonds.csv",
                 index_col=0)

df.head()
# Out:
#    carat  price
# 0   0.23    326
# 1   0.21    326
# 2   0.23    327
# 3   0.29    334
# 4   0.31    335

# %%
# імпорт модуля


# створіть тензори без градієнтів
y = torch.tensor(df['price'].values, dtype=torch.float32, requires_grad=False)
x = torch.tensor(df['carat'].values, dtype=torch.float32, requires_grad=False)

# створіть тензори з градієнтом, оберіть довільне початкове значення
coef = torch.randn(1, requires_grad=True)
intercept = torch.tensor(1.0, requires_grad=True)

# вкажіть навчальний крок
learning_rate = 0.05 # todo: play with

# визначення алгоритму


# основний цикл
for t in range(4000):
  # обрахуйте прогноз моделі за формулою лінійної регресії
  y_pred = coef * x + intercept
  # обрахуйте метрику середньо квадратичного
  # не використовуйте sklearn, лише функції torch
  # див torch.mean
  loss = torch.mean((y_pred - y) ** 2)
  # виведіть значення метрики для кожного сотого кроку
  if t % 100 == 0:
        print(f"Step {t}: Loss = {loss.item()}")
  # обрахуйте градієнти по метриці
  loss.backward()
  # градієнтний спуск
  with torch.no_grad():
      coef -= learning_rate * coef.grad
      intercept -= learning_rate * intercept.grad

      # Обнуляємо градієнти
      coef.grad.zero_()
      intercept.grad.zero_()
# Out:
# Step 0: Loss = 31381832.0
# Step 100: Loss = 2897509.25
# Step 200: Loss = 2434615.5
# Step 300: Loss = 2400645.5
# Step 400: Loss = 2398152.5
# Step 500: Loss = 2397969.5
# Step 600: Loss = 2397956.0
# Step 700: Loss = 2397955.25
# Step 800: Loss = 2397955.25
# Step 900: Loss = 2397955.25
# Step 1000: Loss = 2397955.25
# Step 1100: Loss = 2397955.25
# Step 1200: Loss = 2397955.25
# Step 1300: Loss = 2397955.25
# Step 1400: Loss = 2397955.25
# Step 1500: Loss = 2397955.25
# Step 1600: Loss = 2397955.25
# Step 1700: Loss = 2397955.25
# Step 1800: Loss = 2397955.25
# Step 1900: Loss = 2397955.25
# Step 2000: Loss = 2397955.25
# Step 2100: Loss = 2397955.25
# Step 2200: Loss = 2397955.25
# Step 2300: Loss = 2397955.25
# Step 2400: Loss = 2397955.25
# Step 2500: Loss = 2397955.25
# Step 2600: Loss = 2397955.25
# Step 2700: Loss = 2397955.25
# Step 2800: Loss = 2397955.25
# Step 2900: Loss = 2397955.25
# Step 3000: Loss = 2397955.25
# Step 3100: Loss = 2397955.25
# Step 3200: Loss = 2397955.25
# Step 3300: Loss = 2397955.25
# Step 3400: Loss = 2397955.25
# Step 3500: Loss = 2397955.25
# Step 3600: Loss = 2397955.25
# Step 3700: Loss = 2397955.25
# Step 3800: Loss = 2397955.25
# Step 3900: Loss = 2397955.25

# %% [markdown]
# # Результат

# %%
coef.item(), intercept.item()
# Out:
# (7756.4111328125, -2256.347900390625)

# %% [markdown]
# # Порівняйте результат з sklearn

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
X_train = df.drop(columns=['price'])
y_train = df['price']
# тренування
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.coef_[0], model.intercept_
# Out:
# (7756.425617968435, -2256.360580045403)
